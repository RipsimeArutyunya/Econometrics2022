# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# s = pd.Series()

arr = np.array([1,2,3,4,5])
# arr
# s_from_arr = pd.Series(arr)
# s_from_arr

# s_from_arr = pd.Series(arr, index = ['a','b','c','d','e'])
# s_from_arr

# dict_ = {'a':0, 'b':1, 'c': 2}
# s_from_dict = pd.Series(dict_)
# s_from_dict
# s_from_dict[2]
# s_from_dict[1:]

# df = pd.DataFrame()
# type(df)

# d_from_arr = pd.DataFrame(arr)
# d_from_arr = pd.DataFrame(arr, columns=['Elements'])
# d_from_arr

data = {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}
d_from_dict = pd.DataFrame.from_dict(data)
# d_from_dict
# d_from_dict.columns
d_from_dict.columns = ['A', 'B']
d_from_dict
# Out:
#    A  B
# 0  3  a
# 1  2  b
# 2  1  c
# 3  0  d

# %%
data = [['Alex',10, 2009],['Bob',12, 2011],['Clarke',13, 2012]]
df = pd.DataFrame(data,columns=['Name','Age', 'Year'])
df
# Out:
#      Name  Age  Year
# 0    Alex   10  2009
# 1     Bob   12  2011
# 2  Clarke   13  2012

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df_with_cols_rows = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'b', 'c']) 

# df_with_cols_rows
df_with_cols_rows['a']
# df_with_cols_rows[['b']]
# Out:
# first     1
# second    5
# Name: a, dtype: int64

# %%
df[df['Age']==10]
df[(df['Age']>10) & (df['Year']>2000)]
df['Gender'] = ['male','male','male']
df.drop(0, axis=0, inplace=True)
df.drop('Year', axis=1, inplace=True)
df.columns
df.dtypes()
df.ndim
df.shape
df.head()
df.tail()
df['Name'].value_counts()
df.info() #null value
df.describe()
df.shape
df['Job Title'].unique()
df[['Age', 'Rating']].sum()
help(df.mean())

# %%
# df = pd.read_csv(r'C:\Users\rips\Desktop\Econometrics2022\EconometricsPractice2022\rankmd.csv')

# %%
df = pd.read_csv(r'C:\Users\rips\Desktop\Econometrics2022\EconometricsPractice2022\rankmd.csv',
delimiter=';', encoding='ISO-8859-2')

# %%
df.head()
# Out:
#    FIPS    State   County Unreliable  premature_deathDeaths  \
# 0  1000  Alabama      NaN        NaN                82249.0
# 1  1001  Alabama  Autauga        NaN                  787.0
# 2  1003  Alabama  Baldwin        NaN                 3147.0
# 3  1005  Alabama  Barbour        NaN                  515.0
# 4  1007  Alabama     Bibb        NaN                  476.0
#
#    premature_deathYears_of_Potential_Life_Lost_Rate  \
# 0                                            9820.0
# 1                                            7830.0
# 2                                            7680.0
# 3                                           11477.0
# 4                                           12173.0
#
#    premature_death_95% CILow  premature_death_95% CI - High  \
# 0                     9718.0                         9922.0
# 1                     6998.0                         8662.0
# 2                     7237.0                         8124.0
# 3                     9908.0                        13045.0
# 4                    10506.0                        13839.0
#
#    premature_death_Quartile  premature_death_YPLL Rate (AIAN)  ...  \
# 0                       NaN                            5145.0  ...
# 1                       1.0                               NaN  ...
# 2                       1.0                               NaN  ...
# 3                       3.0                               NaN  ...
# 4                       4.0                               NaN  ...
#
#    drive_alone_to_work_% Drive Alone (Hispanic) 95% CI - High  \
# 0                                               78.0
# 1                                                NaN
# 2                                               83.0
# 3                                                NaN
# 4                                                NaN
#
#    drive_alone_to_work_% Drive Alone (White)  \
# 0                                       87.0
# 1                                       82.0
# 2                                       82.0
# 3                                       86.0
# 4                                        NaN
#
#   drive_alone_to_work_% Drive Alone (White) 95% CI - Low  \
# 0                                               87.0
# 1                                               78.0
# 2                                               80.0
# 3                                               82.0
# 4                                                NaN
#
#    drive_alone_to_work_% Drive Alone (White) 95% CI - High  \
# 0                                               87.0
# 1                                               87.0
# 2                                               84.0
# 3                                               91.0
# 4                                                NaN
#
#    long_commute_driving_alone_# Workers who Drive Alone  \
# 0                                            2073072
# 1                                              24635
# 2                                              93141
# 3                                               8231
# 4                                               8167
#
#    long_commute_driving_alone_% Long Commute - Drives Alone  \
# 0                                                 35
# 1                                                 38
# 2                                                 40
# 3                                                 31
# 4                                                 52
#
#   long_commute_driving_alone_95% CI - Low  \
# 0                                      34
# 1                                      34
# 2                                      38
# 3                                      26
# 4                                      44
#
#    long_commute_driving_alone_95% CI - High  \
# 0                                        35
# 1                                        42
# 2                                        43
# 3                                        36
# 4                                        60
#
#    long_commute_driving_alone_Quartile  Unnamed: 249
# 0                                  NaN           NaN
# 1                                  2.0           NaN
# 2                                  3.0           NaN
# 3                                  2.0           NaN
# 4                                  4.0           NaN
#
# [5 rows x 250 columns]

# %%
df.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Unreliable', 'premature_deathDeaths',
#        'premature_deathYears_of_Potential_Life_Lost_Rate',
#        'premature_death_95% CILow', 'premature_death_95% CI - High',
#        'premature_death_Quartile', 'premature_death_YPLL Rate (AIAN)',
#        ...
#        'drive_alone_to_work_% Drive Alone (Hispanic) 95% CI - High',
#        'drive_alone_to_work_% Drive Alone (White)',
#        'drive_alone_to_work_% Drive Alone (White) 95% CI - Low',
#        'drive_alone_to_work_% Drive Alone (White) 95% CI - High',
#        'long_commute_driving_alone_# Workers who Drive Alone',
#        'long_commute_driving_alone_% Long Commute - Drives Alone',
#        'long_commute_driving_alone_95% CI - Low',
#        'long_commute_driving_alone_95% CI - High',
#        'long_commute_driving_alone_Quartile', 'Unnamed: 249'],
#       dtype='object', length=250)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3193 entries, 0 to 3192
# Columns: 250 entries, FIPS to Unnamed: 249
# dtypes: float64(194), int64(34), object(22)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#                FIPS  premature_deathDeaths  \
# count   3193.000000            2906.000000
# mean   30360.922643            2648.745010
# std    15171.912105           14271.324476
# min     1000.000000              38.000000
# 25%    18173.000000             228.000000
# 50%    29175.000000             487.000000
# 75%    45075.000000            1191.000000
# max    56045.000000          350612.000000
#
#        premature_deathYears_of_Potential_Life_Lost_Rate  \
# count                                       2906.000000
# mean                                        8540.433242
# std                                         2609.735185
# min                                         2821.000000
# 25%                                         6700.750000
# 50%                                         8252.000000
# 75%                                        10011.250000
# max                                        25033.000000
#
#        premature_death_95% CILow  premature_death_95% CI - High  \
# count                2906.000000                    2906.000000
# mean                 7206.932553                    9919.600138
# std                  2241.231557                    3209.520314
# min                  2001.000000                    3059.000000
# 25%                  5624.000000                    7698.250000
# 50%                  6974.500000                    9529.500000
# 75%                  8518.000000                   11656.000000
# max                 21974.000000                   32457.000000
#
#        premature_death_Quartile  premature_death_YPLL Rate (AIAN)  \
# count               3081.000000                        226.000000
# mean                   2.458942                      13916.283186
# std                    1.117025                       6476.752502
# min                    1.000000                       2303.000000
# 25%                    1.000000                       9524.500000
# 50%                    2.000000                      13557.500000
# 75%                    3.000000                      17581.000000
# max                    5.000000                      36330.000000
#
#        premature_death_YPLL Rate (AIAN) 95% CI - Low  \
# count                                     226.000000
# mean                                    10734.336283
# std                                      5202.774092
# min                                       926.000000
# 25%                                      7129.750000
# 50%                                     10099.000000
# 75%                                     13629.500000
# max                                     28758.000000
#
#        premature_death_YPLL Rate (AIAN) 95% CI - High  \
# count                                      226.000000
# mean                                     17679.880531
# std                                       8423.822344
# min                                       3282.000000
# 25%                                      11936.750000
# 50%                                      16856.000000
# 75%                                      22213.250000
# max                                      45490.000000
#
#        premature_death_YPLL Rate (Asian)  ...  \
# count                         284.000000  ...
# mean                         3502.616197  ...
# std                          1443.240833  ...
# min                          1567.000000  ...
# 25%                          2575.750000  ...
# 50%                          3193.500000  ...
# 75%                          3925.750000  ...
# max                         14340.000000  ...
#
#        drive_alone_to_work_% Drive Alone (Hispanic) 95% CI - High  \
# count                                        1346.000000
# mean                                           80.189450
# std                                            10.064723
# min                                             7.000000
# 25%                                            75.000000
# 50%                                            81.000000
# 75%                                            87.000000
# max                                           100.000000
#
#        drive_alone_to_work_% Drive Alone (White)  \
# count                                1793.000000
# mean                                   80.986057
# std                                     7.556582
# min                                    10.000000
# 25%                                    79.000000
# 50%                                    82.000000
# 75%                                    85.000000
# max                                    95.000000
#
#        drive_alone_to_work_% Drive Alone (White) 95% CI - Low  \
# count                                        1793.000000
# mean                                           77.838818
# std                                             8.634584
# min                                             8.000000
# 25%                                            75.000000
# 50%                                            80.000000
# 75%                                            83.000000
# max                                            91.000000
#
#        drive_alone_to_work_% Drive Alone (White) 95% CI - High  \
# count                                        1793.000000
# mean                                           84.118795
# std                                             7.472408
# min                                            10.000000
# 25%                                            82.000000
# 50%                                            85.000000
# 75%                                            88.000000
# max                                           100.000000
#
#        long_commute_driving_alone_# Workers who Drive Alone  \
# count                                       3.193000e+03
# mean                                        9.566914e+04
# std                                         5.832044e+05
# min                                         3.300000e+01
# 25%                                         4.543000e+03
# 50%                                         1.103300e+04
# 75%                                         3.179400e+04
# max                                         1.819156e+07
#
#        long_commute_driving_alone_% Long Commute - Drives Alone  \
# count                                        3193.000000
# mean                                           32.016286
# std                                            12.615794
# min                                             0.000000
# 25%                                            22.000000
# 50%                                            32.000000
# 75%                                            41.000000
# max                                            73.000000
#
#        long_commute_driving_alone_95% CI - Low  \
# count                              3193.000000
# mean                                 27.256185
# std                                  12.092071
# min                                   0.000000
# 25%                                  18.000000
# 50%                                  27.000000
# 75%                                  36.000000
# max                                  65.000000
#
#        long_commute_driving_alone_95% CI - High  \
# count                               3193.000000
# mean                                  36.828375
# std                                   13.920671
# min                                    2.000000
# 25%                                   26.000000
# 50%                                   36.000000
# 75%                                   46.000000
# max                                  100.000000
#
#        long_commute_driving_alone_Quartile  Unnamed: 249
# count                          3081.000000           0.0
# mean                              2.492697           NaN
# std                               1.120947           NaN
# min                               1.000000           NaN
# 25%                               1.000000           NaN
# 50%                               2.000000           NaN
# 75%                               3.000000           NaN
# max                               5.000000           NaN
#
# [8 rows x 228 columns]

# %%
# df.ndim
# df.size
df.shape
# Out:
# (3193, 250)

# %%
df.columns
# Out:
# Index(['FIPS', 'State', 'County', 'Unreliable', 'premature_deathDeaths',
#        'premature_deathYears_of_Potential_Life_Lost_Rate',
#        'premature_death_95% CILow', 'premature_death_95% CI - High',
#        'premature_death_Quartile', 'premature_death_YPLL Rate (AIAN)',
#        ...
#        'drive_alone_to_work_% Drive Alone (Hispanic) 95% CI - High',
#        'drive_alone_to_work_% Drive Alone (White)',
#        'drive_alone_to_work_% Drive Alone (White) 95% CI - Low',
#        'drive_alone_to_work_% Drive Alone (White) 95% CI - High',
#        'long_commute_driving_alone_# Workers who Drive Alone',
#        'long_commute_driving_alone_% Long Commute - Drives Alone',
#        'long_commute_driving_alone_95% CI - Low',
#        'long_commute_driving_alone_95% CI - High',
#        'long_commute_driving_alone_Quartile', 'Unnamed: 249'],
#       dtype='object', length=250)

# %%
df['premature_deathDeaths'].max()
# Out:
# 350612.0

# %%
sns.distplot(df['poor-ors_fair_health_% Fair or Poor Health'])
# Out:
# C:\Users\rips\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='poor-or_fair_health_% Fair or Poor Health', ylabel='Density'>
